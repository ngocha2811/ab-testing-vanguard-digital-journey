# %%
import pandas as pd
import numpy as np

# %%
df_web_pt1 = pd.read_csv("https://raw.githubusercontent.com/ngocha2811/ab-testing-vanguard-digital-journey/refs/heads/main/data/raw/df_final_web_data_pt_1.csv")
df_web_pt2 = pd.read_csv("https://raw.githubusercontent.com/ngocha2811/ab-testing-vanguard-digital-journey/refs/heads/main/data/raw/df_final_web_data_pt_2.csv")

df_web = pd.concat([df_web_pt1, df_web_pt2], ignore_index=True)

df_demo = pd.read_csv("https://raw.githubusercontent.com/ngocha2811/ab-testing-vanguard-digital-journey/refs/heads/main/data/raw/df_final_demo.csv")
df_variation = pd.read_csv("https://raw.githubusercontent.com/ngocha2811/ab-testing-vanguard-digital-journey/refs/heads/main/data/raw/df_final_experiment_clients.csv")

# %%
display(df_web)
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_web.dtypes
# Out:
# client_id        int64
# visitor_id      object
# visit_id        object
# process_step    object
# date_time       object
# dtype: object

# %%
### Check for Anomalies
## Nulls
## Duplicates
## Anomalies

# %%
df_demo.isna().sum()
# Out:
# client_id            0
# clnt_tenure_yr      14
# clnt_tenure_mnth    14
# clnt_age            15
# gendr               14
# num_accts           14
# bal                 14
# calls_6_mnth        14
# logons_6_mnth       14
# dtype: int64

# %%
df_web.isna().sum()
# Out:
# client_id       0
# visitor_id      0
# visit_id        0
# process_step    0
# date_time       0
# dtype: int64

# %%
df_variation.isna().sum()
# Out:
# client_id        0
# Variation    20109
# dtype: int64

# %%
### Cleaning df_demo

df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
for col in df_demo.select_dtypes(include="number").columns:
    col_median = df_demo[col].median()
    df_demo[col].fillna(col_median, inplace=True)
# Out:
# /var/folders/z1/hpkmqfl54717zbjq651n7__40000gn/T/ipykernel_74479/224476067.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_demo[col].fillna(col_median, inplace=True)

# %%
df_demo["gendr"].mode()[0]

df_demo["gendr"].fillna(df_demo["gendr"].mode()[0], inplace=True)
# Out:
# /var/folders/z1/hpkmqfl54717zbjq651n7__40000gn/T/ipykernel_74479/1084669219.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_demo["gendr"].fillna(df_demo["gendr"].mode()[0], inplace=True)

# %%
df_demo.isna().sum()
# Out:
# client_id           0
# clnt_tenure_yr      0
# clnt_tenure_mnth    0
# clnt_age            0
# gendr               0
# num_accts           0
# bal                 0
# calls_6_mnth        0
# logons_6_mnth       0
# dtype: int64

# %%
### Cleaning df_variation

df_variation.dropna(inplace=True)

# %%
df_web
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 755400    9668240   388766751_9038881013   922267647_3096648104_968866
# 755401    9668240   388766751_9038881013   922267647_3096648104_968866
# 755402    9668240   388766751_9038881013   922267647_3096648104_968866
# 755403    9668240   388766751_9038881013   922267647_3096648104_968866
# 755404     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
df_web = pd.merge(left = df_web, right = df_variation, on = "client_id", how="inner")

# %%
df_web.dropna(inplace=True)

# %%
df_web
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 321304    1574008  117364417_77840596075  528720790_71583064618_169151
# 321305    2908510  814969699_90652851448   562606085_36368381773_92090
# 321306    2908510  814969699_90652851448   562606085_36368381773_92090
# 321307    2908510  814969699_90652851448   562606085_36368381773_92090
# 321308    2908510  814969699_90652851448   562606085_36368381773_92090
#
#        process_step            date_time Variation
# 0            step_3  2017-04-17 15:27:07      Test
# ...

# %%
### Duplicates

df_web.duplicated().sum()

df_web.drop_duplicates(inplace=True)

# %%
df_demo.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_variation.duplicated().sum()
# Out:
# np.int64(0)

# %%
df_variation
# Out:
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 50495     393005   Control
# 50496    2908510   Control
# 50497    7230446      Test
# 50498    5230357      Test
# 50499    6334360      Test
#
# [50500 rows x 2 columns]

# %%
df_demo
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
df_web.to_csv("../data/clean/df_web.csv", index=False)
df_demo.to_csv("../data/clean/df_demo.csv", index=False)
df_variation.to_csv("../data/clean/df_variation.csv", index=False)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_web.to_csv("../data/clean/df_web.csv", index=False)
#       2 df_demo.to_csv("../data/clean/df_demo.csv", index=False)
#       3 df_variation.to_csv("../data/clean/df_variation.csv", index=False)
#
# File /opt/anaconda3/lib/python3.13/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# ...
